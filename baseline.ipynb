# %%
# !git clone https://github.com/speechbrain/speechbrain.git
# %cd speechbrain
# %pip install -r requirements.txt
# %pip install --editable .
# %cd recipes/LibriSpeech/ASR/transformer/
# %pip install -r extra_requirements.txt
# Out:
# c:\Users\ismail\Documents\blg477e-spring\speechbrain
# fatal: destination path 'speechbrain' already exists and is not an empty directory.
# c:\Users\ismail\Documents\blg477e-spring\.venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ...
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\ismail\Documents\blg477e-spring\speechbrain\recipes\LibriSpeech\ASR\transformer
# ...
# Note: you may need to restart the kernel to use updated packages.
# Obtaining file:///C:/Users/ismail/Documents/blg477e-spring/speechbrain
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
# ...

# %%
# !ln -s ../../librispeech_prepare.py librispeech_prepare.py
# !torchrun --nproc_per_node=2  train.py hparams/hyperconformer_8M.yaml --output_folder /kaggle/working/results/hyperconformer_8M/baseline/7775 --data_folder /kaggle/input/datasets/smailft/librispeech100h/LibriSpeech --train_splits '["train-clean-100"]' --batch_size 8 --grad_accumulation_factor 2
